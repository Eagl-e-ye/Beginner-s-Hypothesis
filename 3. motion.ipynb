# %% [markdown]
# # motion: LogisticRegression

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
train_video_features= np.load(r"C:\Users\indra\Desktop\DSG PROJECT\video_features_noiseless_grayscale_resnet101.npy")
df= pd.read_csv(r'C:\Users\indra\Desktop\DSG PROJECT\BH25\Training_Data\train.csv')

# since the motions are continuous value and the computer understands only number, the motions are label encoded before training
le = LabelEncoder()
df["motion"] = le.fit_transform(df["motion"])

# %%
df
# Out:
#       video_id element  motion power  speed          video_summary
# 0            1    Erde       1   rot    9.6     (3.8147, 31.94809)
# 1            2   Feuer       3  grin    9.6   (26.70288, -4.29153)
# 2            3   Feuer       2  gelb    9.6      (3.8147, 8.58307)
# 3            4    Erde       4  lila    6.9  (-24.79553, -0.95367)
# 4            5    Erde       1  lila    9.6    (7.62939, 22.88818)
# ...        ...     ...     ...   ...    ...                    ...
# 9995      9996   Feuer       4   rot    9.6  (-1.90735, -11.44409)
# 9996      9997  Wasser       3  gelb    9.6        (0.0, 13.14282)
# 9997      9998   Feuer       0  lila    6.9   (17.64297, 10.49042)
# 9998      9999   Boden       4  gelb    9.6  (-21.45767, 11.44409)
# 9999     10000    Luft       4  gelb    6.9   (-18.11981, -6.4373)
#
# [10000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
label= df["motion"] # label is defined for y value of the model
X_train, X_val, y_train, y_val = train_test_split(train_video_features, label, test_size=0.2, random_state=42)

# %%
#logistic regression is used for this model
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression(max_iter=10000)
model.fit(train_video_features, label)
# Out:
# LogisticRegression(max_iter=10000)

# %%
model.score(X_val, y_val) # checked the eval accuracy on seen data
# Out:
# 0.9895

# %%
import joblib
joblib.dump(model, './motion_model.pkl') 
# the model is saved for further use
# Out:
# ['./motion_model.pkl']

# %%
joblib.dump(le, 'label_encoder_motion.pkl')
# the label encodes are used for further use
# Out:
# ['label_encoder_motion.pkl']
